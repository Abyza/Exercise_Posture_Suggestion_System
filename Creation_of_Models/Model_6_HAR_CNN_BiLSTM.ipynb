# %% [markdown]
# # Dataset

# %%
import pandas as pd
import numpy as np
import cv2
from keras.utils import Sequence
from matplotlib.pyplot import imshow
import os

# %%
# !pip install remotezip tqdm opencv-python einops imageio
# !pip install -U tensorflow keras
# Out:
# Collecting remotezip
#   Downloading remotezip-0.12.3-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.31.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2024.7.4)
# Installing collected packages: einops, remotezip
# Successfully installed einops-0.8.0 remotezip-0.12.3
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.7 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 71.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Installing collected packages: namex, optree, ml-dtypes, h5py, tensorboard, keras, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.17.0 which is incompatible.
# Successfully installed h5py-3.11.0 keras-3.4.1 ml-dtypes-0.4.0 namex-0.0.8 optree-0.12.1 tensorboard-2.17.0 tensorflow-2.17.0

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import einops
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class_labels = ['Squats', 'Lunges', 'PushUps']

root_path = '/content/drive/MyDrive/3RD YR. - 2ND SEM./CPE 313/Final Project/'
# root_path = '/content/drive/MyDrive/'
data_path = root_path + "dataset/ucf101/"

HEIGHT = 244
WIDTH = 244
FRAMES = 15

# %%
def list_files_per_class(zip_url):
  """
    List the files in each class of the dataset given the zip URL.

    Args:
      zip_url: URL from which the files can be unzipped.

    Return:
      files: List of files in each of the classes.
  """
  files = []
  with rz.RemoteZip(URL) as zip:
    for zip_info in zip.infolist():
      files.append(zip_info.filename)
  return files

def get_class(fname):
  """
    Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Return:
      Class that the file belongs to.
  """
  return fname.split('_')[-3]

def get_files_per_class(files):
  """
    Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Return:
      Dictionary of class names (key) and files (values).
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

def download_from_zip(zip_url, to_dir, file_names):
  """
    Download the contents of the zip file from the zip URL.

    Args:
      zip_url: Zip URL containing data.
      to_dir: Directory to download data to.
      file_names: Names of files to download.
  """
  with rz.RemoteZip(zip_url) as zip:
    for fn in tqdm.tqdm(file_names):
      class_name = get_class(fn)
      zip.extract(fn, str(to_dir / class_name))
      unzipped_file = to_dir / class_name / fn

      fn = pathlib.Path(fn).parts[-1]
      output_file = to_dir / class_name / fn
      unzipped_file.rename(output_file,)

def split_class_lists(files_for_class, count):
  """
    Returns the list of files belonging to a subset of data as well as the remainder of
    files that need to be downloaded.

    Args:
      files_for_class: Files belonging to a particular class of data.
      count: Number of files to download.

    Return:
      split_files: Files belonging to the subset of data.
      remainder: Dictionary of the remainder of files that need to be downloaded.
  """
  split_files = []
  remainder = {}
  for cls in files_for_class:
    split_files.extend(files_for_class[cls][:count])
    remainder[cls] = files_for_class[cls][count:]
  return split_files, remainder

import random
from pathlib import Path

def download_ufc_101_subset(zip_url, num_classes, splits, download_dir, selected_classes):
    """
    Download a subset of the UFC101 dataset and split them into various parts, such as
    training, validation, and test.

    Args:
      zip_url: Zip URL containing data.
      num_classes: Number of labels.
      splits: Dictionary specifying the training, validation, test, etc. (key) division of data
              (value is number of files per split).
      download_dir: Directory to download data to.
      selected_classes: List of selected classes to download.

    Return:
      dir: Posix path of the resulting directories containing the splits of data.
    """
    random.seed(191919)

    # Retrieve file list and organize them by class
    files = list_files_per_class(zip_url)
    for f in files:
        tokens = f.split('/')
        if len(tokens) <= 2:
            files.remove(f)  # Remove items without filenames

    files_for_class = get_files_per_class(files)

    # Filter classes based on selected_classes
    classes = [cls for cls in selected_classes if cls in files_for_class.keys()]

    # Shuffle files for each selected class
    for cls in classes:
        new_files_for_class = files_for_class[cls]
        random.shuffle(new_files_for_class)
        files_for_class[cls] = new_files_for_class

    # Keep only the number of classes specified
    files_for_class = {cls: files_for_class[cls] for cls in classes[:num_classes]}

    dirs = {}
    for split_name, split_count in splits.items():
        print(split_name, ":")
        split_dir = Path(download_dir) / split_name
        split_files, files_for_class = split_class_lists(files_for_class, split_count)
        download_from_zip(zip_url, split_dir, split_files)
        dirs[split_name] = split_dir

    return dirs

def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded.
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

def frames_from_video_file(video_path, n_frames, output_size = (WIDTH, HEIGHT), frame_step = 2):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label.

      Args:
        path: Video file paths.
        n_frames: Number of frames.
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths]
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames)
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
# !pip install imgaug
# Out:
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug) (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.0.5)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (3.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (2024.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (2.8.2)

# %%
import imgaug.augmenters as iaa
import random
from pathlib import Path

class FrameGenerator:
    def __init__(self, path, n_frames, training=False):
        self.path = Path(path)
        self.n_frames = n_frames
        self.training = training
        self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
        self.class_ids_for_name = {name: idx for idx, name in enumerate(self.class_names)}

        self.generate_augmentor()

    def generate_augmentor(self):
      # Define augmentation pipeline for video frames
        sequence = []

        if random.random() < 0.5:
          sequence.append(iaa.Fliplr(1))

        if random.random() < 0.5:
          sequence.append(iaa.Affine(rotate=45))

        if random.random() < 0.5:
          sequence.append(iaa.GaussianBlur(sigma=(1, 2)))

        if random.random() < 0.5:
          sequence.append(iaa.Sharpen(alpha=(0, 1)))

        self.augmentor = iaa.Sequential(sequence)

    def get_files_and_class_names(self):
        video_paths = list(self.path.glob('*/*.avi'))
        classes = [p.parent.name for p in video_paths]
        return video_paths, classes

    def augment_video_frames(self, video_frames):
        if self.training:
            augmented_frames = self.augmentor(images=video_frames)
            return augmented_frames
        else:
            return video_frames

    def __call__(self):
        self.generate_augmentor()
        video_paths, classes = self.get_files_and_class_names()

        pairs = list(zip(video_paths, classes))

        if self.training:
            random.shuffle(pairs)

        for path, name in pairs:
            # Read video frames from the video file
            frame_step = random.randint(3, 8)
            video_frames = frames_from_video_file(path, self.n_frames, frame_step=frame_step)
            video_frames_aug = self.augment_video_frames(video_frames)
            label = self.class_ids_for_name[name]  # Encode labels
            yield video_frames_aug, label

# %%
URL = 'https://storage.googleapis.com/thumos14_files/UCF101_videos.zip'
download_dir = pathlib.Path('./UCF101_subset/')
subset_paths = download_ufc_101_subset(URL,
                        num_classes = 3,
                        splits = {"train": 40, "val": 10, "test": 5},
                        download_dir = download_dir,
                    selected_classes = ['BodyWeightSquats', 'Lunges', 'PushUps'])
# Out:
# train :
# 100%|██████████| 120/120 [02:38<00:00,  1.32s/it]
# val :
# 100%|██████████| 30/30 [00:52<00:00,  1.76s/it]
# test :
# 100%|██████████| 11/11 [00:18<00:00,  1.67s/it]

# %%
n_frames = 15
batch_size = 10

output_signature = (tf.TensorSpec(shape = (FRAMES, WIDTH, HEIGHT, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['train'], n_frames, training=True),
                                          output_signature = output_signature)


# Batch the data
train_ds = train_ds.batch(batch_size)

val_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['val'], n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)

test_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['test'], n_frames),
                                         output_signature = output_signature)

test_ds = test_ds.batch(batch_size)

# %%
def plot_frames(frames, label):
    plt.figure(figsize=(16, 8))
    for i in range(len(frames)):
        ax = plt.subplot(2, 8, i + 1)
        plt.imshow(frames[i].astype("float32"))
        plt.title(f"Frame {i+1}")
        plt.axis("off")
    plt.suptitle(f"Label: {class_labels[label]}")
    plt.show()

for frames_batch, labels_batch in train_ds.take(40):
    frames = frames_batch[7].numpy()  # Convert the tensor to numpy array
    label = labels_batch[7].numpy()  # Convert the tensor to numpy array
    plot_frames(frames, label)
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Model Training

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Sequential

# %%
def build_3d_cnn(input_shape=(FRAMES, WIDTH, HEIGHT, 3)):
    model = Sequential()

    # First Conv Block
    model.add(layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    # Second Conv Block
    model.add(layers.Conv3D(64, (3, 3, 3), activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    # Third Conv Block
    model.add(layers.Conv3D(128, (3, 3, 3), activation='relu'))
    model.add(layers.Conv3D(128, (3, 3, 3), activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    # Fourth Conv Block
    model.add(layers.Conv3D(256, (2, 2, 2), activation='relu'))
    model.add(layers.Conv3D(256, (2, 2, 2), activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Reshape((6, -1)))

    model.add(layers.Bidirectional(layers.LSTM(128, return_sequences=True)))
    model.add(layers.Bidirectional(layers.LSTM(64)))

    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))

    model.add(layers.Dense(3))

    return model

# %%
model = build_3d_cnn()
model.compile(optimizer='adam', loss='sparsecategorical_entropy')

model.summary(expand_nested=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                      │ (None, 13, 242, 242, 32)    │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 13, 121, 121, 32)    │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_1 (Conv3D)                    │ (None, 11, 119, 119, 64)    │          55,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 11, 59, 59, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_2 (Conv3D)                    │ (None, 9, 57, 57, 128)      │         221,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_3 (Conv3D)                    │ (None, 7, 55, 55, 128)      │         442,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_2 (MaxPooling3D)       │ (None, 7, 27, 27, 128)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_4 (Conv3D)                    │ (None, 6, 26, 26, 256)      │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_5 (Conv3D)                    │ (None, 5, 25, 25, 256)      │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_3 (MaxPooling3D)       │ (None, 5, 12, 12, 256)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 5, 12, 12, 1024)     │         263,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5, 12, 12, 512)      │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 6, 61440)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 6, 256)              │      63,046,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │          66,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 65,639,811 (250.40 MB)
#  Trainable params: 65,639,811 (250.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Visualize the model
keras.utils.plot_model(model, expand_nested=True, dpi=60, show_shapes=True)

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer = keras.optimizers.Adam(learning_rate = 0.00001),
              metrics = ['accuracy'])

checkpoint = keras.callbacks.ModelCheckpoint(root_path + 'models/3DCNN-BiLSTM.keras', monitor='val_accuracy', save_best_only=True, mode='max')

# %%
epochs = 100

history = model.fit(x = train_ds,
                    epochs = epochs,
                    validation_data = val_ds)
# Out:
# Epoch 1/100
#      12/Unknown 46s 2s/step - accuracy: 0.2657 - loss: 1.0991
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.2671 - loss: 1.0991 - val_accuracy: 0.3333 - val_loss: 1.0980
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.3552 - loss: 1.0973 - val_accuracy: 0.3333 - val_loss: 1.0968
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.2954 - loss: 1.0999 - val_accuracy: 0.3333 - val_loss: 1.0968
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.3629 - loss: 1.0943 - val_accuracy: 0.3333 - val_loss: 1.0965
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.3119 - loss: 1.0978 - val_accuracy: 0.3333 - val_loss: 1.0940
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.2831 - loss: 1.0992 - val_accuracy: 0.3333 - val_loss: 1.0941
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.3292 - loss: 1.0925 - val_accuracy: 0.3333 - val_loss: 1.0903
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.3381 - loss: 1.0900 - val_accuracy: 0.3333 - val_loss: 1.0932
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.3079 - loss: 1.0935 - val_accuracy: 0.3667 - val_loss: 1.0867
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.3900 - loss: 1.0924 - val_accuracy: 0.4000 - val_loss: 1.0824
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.3749 - loss: 1.0788 - val_accuracy: 0.3333 - val_loss: 1.1054
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.4130 - loss: 1.0588 - val_accuracy: 0.3667 - val_loss: 1.0540
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.4393 - loss: 1.0688 - val_accuracy: 0.3333 - val_loss: 1.0662
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.4785 - loss: 1.0290 - val_accuracy: 0.3667 - val_loss: 1.0761
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.4612 - loss: 1.0419 - val_accuracy: 0.3333 - val_loss: 1.0425
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.5138 - loss: 0.9786 - val_accuracy: 0.3667 - val_loss: 1.0967
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.4760 - loss: 1.0630 - val_accuracy: 0.3333 - val_loss: 1.0894
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.4249 - loss: 1.0320 - val_accuracy: 0.4667 - val_loss: 1.0210
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.4844 - loss: 0.9999 - val_accuracy: 0.3333 - val_loss: 1.1145
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.5000 - loss: 1.0165 - val_accuracy: 0.4000 - val_loss: 1.1418
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.4647 - loss: 1.0074 - val_accuracy: 0.3667 - val_loss: 1.1431
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.4450 - loss: 1.0324 - val_accuracy: 0.5333 - val_loss: 1.0154
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5504 - loss: 0.9978 - val_accuracy: 0.4333 - val_loss: 1.0547
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5559 - loss: 0.9764 - val_accuracy: 0.4000 - val_loss: 1.1195
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.4605 - loss: 1.0493 - val_accuracy: 0.4000 - val_loss: 1.1025
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.4993 - loss: 0.9754 - val_accuracy: 0.5000 - val_loss: 0.9612
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5619 - loss: 0.9450 - val_accuracy: 0.4667 - val_loss: 1.0942
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6433 - loss: 0.8819 - val_accuracy: 0.5000 - val_loss: 0.9890
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6904 - loss: 0.8372 - val_accuracy: 0.4667 - val_loss: 1.0215
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6187 - loss: 0.8943 - val_accuracy: 0.4667 - val_loss: 0.9169
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5718 - loss: 0.8986 - val_accuracy: 0.4667 - val_loss: 0.9899
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.6543 - loss: 0.8365 - val_accuracy: 0.4667 - val_loss: 1.1470
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5734 - loss: 0.9475 - val_accuracy: 0.5000 - val_loss: 0.9831
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.7453 - loss: 0.7773 - val_accuracy: 0.5000 - val_loss: 1.0519
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.5753 - loss: 0.8918 - val_accuracy: 0.5000 - val_loss: 1.0726
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6576 - loss: 0.8258 - val_accuracy: 0.4000 - val_loss: 1.0203
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.6753 - loss: 0.8076 - val_accuracy: 0.6000 - val_loss: 0.9892
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.6291 - loss: 0.8073 - val_accuracy: 0.6333 - val_loss: 0.9368
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7301 - loss: 0.7131 - val_accuracy: 0.6000 - val_loss: 0.9201
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6317 - loss: 0.9311 - val_accuracy: 0.4667 - val_loss: 1.2821
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.4655 - loss: 1.1269 - val_accuracy: 0.4667 - val_loss: 1.0171
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.6706 - loss: 0.9163 - val_accuracy: 0.5667 - val_loss: 0.9657
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.5249 - loss: 0.9044 - val_accuracy: 0.6667 - val_loss: 0.9420
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.5587 - loss: 0.9475 - val_accuracy: 0.4000 - val_loss: 1.0982
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7129 - loss: 0.7801 - val_accuracy: 0.4667 - val_loss: 1.0208
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6428 - loss: 0.8623 - val_accuracy: 0.4667 - val_loss: 1.0013
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.5199 - loss: 0.9428 - val_accuracy: 0.6000 - val_loss: 0.9516
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.7023 - loss: 0.7546 - val_accuracy: 0.6333 - val_loss: 0.7895
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.4915 - loss: 1.0550 - val_accuracy: 0.4333 - val_loss: 1.1065
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.5557 - loss: 0.9303 - val_accuracy: 0.5667 - val_loss: 0.9405
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5973 - loss: 0.8833 - val_accuracy: 0.6000 - val_loss: 0.8614
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7200 - loss: 0.7566 - val_accuracy: 0.5333 - val_loss: 0.9480
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.6679 - loss: 0.7732 - val_accuracy: 0.5667 - val_loss: 0.8744
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.6507 - loss: 0.7424 - val_accuracy: 0.6000 - val_loss: 0.8692
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.6940 - loss: 0.7173 - val_accuracy: 0.6000 - val_loss: 0.8420
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7731 - loss: 0.6575 - val_accuracy: 0.7000 - val_loss: 0.8656
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.7004 - loss: 0.7657 - val_accuracy: 0.6000 - val_loss: 0.9881
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5219 - loss: 1.0071 - val_accuracy: 0.5000 - val_loss: 1.0358
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7233 - loss: 0.7248 - val_accuracy: 0.4667 - val_loss: 1.1736
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.4799 - loss: 1.2287 - val_accuracy: 0.4667 - val_loss: 1.0515
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.5175 - loss: 1.0654 - val_accuracy: 0.4333 - val_loss: 1.1023
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.6103 - loss: 0.8718 - val_accuracy: 0.4667 - val_loss: 1.1347
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.6342 - loss: 0.8228 - val_accuracy: 0.7000 - val_loss: 0.9306
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6344 - loss: 0.8196 - val_accuracy: 0.6333 - val_loss: 0.9197
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.7186 - loss: 0.6943 - val_accuracy: 0.3667 - val_loss: 1.2992
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.6260 - loss: 0.8065 - val_accuracy: 0.5000 - val_loss: 1.0815
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6674 - loss: 0.7901 - val_accuracy: 0.6667 - val_loss: 0.9104
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6807 - loss: 0.7286 - val_accuracy: 0.4333 - val_loss: 1.1960
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7199 - loss: 0.7417 - val_accuracy: 0.6333 - val_loss: 0.9008
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.6537 - loss: 0.7738 - val_accuracy: 0.3667 - val_loss: 1.4296
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.4584 - loss: 1.1535 - val_accuracy: 0.5667 - val_loss: 1.2143
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5271 - loss: 1.0425 - val_accuracy: 0.4333 - val_loss: 1.0935
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5046 - loss: 0.9786 - val_accuracy: 0.5667 - val_loss: 0.9654
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7143 - loss: 0.7589 - val_accuracy: 0.5333 - val_loss: 0.9810
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6991 - loss: 0.7932 - val_accuracy: 0.5667 - val_loss: 0.9726
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7039 - loss: 0.7652 - val_accuracy: 0.7333 - val_loss: 0.7650
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.7240 - loss: 0.6707 - val_accuracy: 0.6000 - val_loss: 0.8561
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7762 - loss: 0.6190 - val_accuracy: 0.7667 - val_loss: 0.7826
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7298 - loss: 0.7252 - val_accuracy: 0.6000 - val_loss: 0.8787
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6426 - loss: 0.8235 - val_accuracy: 0.5000 - val_loss: 1.0683
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.5985 - loss: 0.9434 - val_accuracy: 0.5000 - val_loss: 1.0903
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.6662 - loss: 0.8627 - val_accuracy: 0.6333 - val_loss: 0.8133
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.7523 - loss: 0.6553 - val_accuracy: 0.7000 - val_loss: 0.8547
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8047 - loss: 0.5799 - val_accuracy: 0.5333 - val_loss: 1.0167
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7129 - loss: 0.6965 - val_accuracy: 0.7667 - val_loss: 0.6710
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7432 - loss: 0.6923 - val_accuracy: 0.6000 - val_loss: 0.9283
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.6966 - loss: 0.7627 - val_accuracy: 0.7000 - val_loss: 0.7898
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.7106 - loss: 0.6786 - val_accuracy: 0.7000 - val_loss: 0.8244
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5460 - loss: 0.9895 - val_accuracy: 0.4667 - val_loss: 1.2135
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7043 - loss: 0.6898 - val_accuracy: 0.4667 - val_loss: 1.0239
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7182 - loss: 0.6780 - val_accuracy: 0.5333 - val_loss: 1.1331
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.7221 - loss: 0.7081 - val_accuracy: 0.4667 - val_loss: 1.1938
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.5837 - loss: 0.8870 - val_accuracy: 0.6333 - val_loss: 0.8140
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7247 - loss: 0.7201 - val_accuracy: 0.6667 - val_loss: 0.7581
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.5622 - loss: 0.9601 - val_accuracy: 0.4667 - val_loss: 1.2575
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5006 - loss: 1.0512 - val_accuracy: 0.4667 - val_loss: 0.9851
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7012 - loss: 0.7181 - val_accuracy: 0.6333 - val_loss: 0.7450
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.6576 - loss: 0.7465 - val_accuracy: 0.3667 - val_loss: 1.3619
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.6584 - loss: 0.7789 - val_accuracy: 0.6333 - val_loss: 0.8175
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.6400 - loss: 0.7348 - val_accuracy: 0.7333 - val_loss: 0.7458

# %%
np.save(root_path + f'models/CNN-BiLSTM_1', history.history)
model.save(root_path + 'models/CNN-BiLSTM_1.keras')

# %%
epochs = 100

history = model.fit(x = train_ds,
                    epochs = epochs,
                    validation_data = val_ds)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.8102 - loss: 0.6284 - val_accuracy: 0.6667 - val_loss: 0.8715
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8275 - loss: 0.5909 - val_accuracy: 0.7333 - val_loss: 0.6698
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.7498 - loss: 0.6317 - val_accuracy: 0.6667 - val_loss: 0.7769
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7732 - loss: 0.5879 - val_accuracy: 0.6667 - val_loss: 0.7851
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8124 - loss: 0.5588 - val_accuracy: 0.7000 - val_loss: 0.7111
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.5936 - loss: 1.0142 - val_accuracy: 0.4667 - val_loss: 1.3809
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7455 - loss: 0.6524 - val_accuracy: 0.5667 - val_loss: 1.0821
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6767 - loss: 0.7223 - val_accuracy: 0.7000 - val_loss: 0.7626
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5246 - loss: 1.0295 - val_accuracy: 0.4333 - val_loss: 1.1965
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5658 - loss: 0.9083 - val_accuracy: 0.5667 - val_loss: 0.8403
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.6963 - loss: 0.7380 - val_accuracy: 0.4333 - val_loss: 1.0974
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6896 - loss: 0.7732 - val_accuracy: 0.6000 - val_loss: 0.9363
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6705 - loss: 0.7744 - val_accuracy: 0.5000 - val_loss: 1.1009
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7019 - loss: 0.7470 - val_accuracy: 0.6000 - val_loss: 0.8428
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.8146 - loss: 0.5524 - val_accuracy: 0.7333 - val_loss: 0.6722
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7286 - loss: 0.6155 - val_accuracy: 0.7000 - val_loss: 0.8098
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.7877 - loss: 0.5585 - val_accuracy: 0.5667 - val_loss: 1.1233
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.6881 - loss: 0.6903 - val_accuracy: 0.7000 - val_loss: 0.8014
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.7169 - loss: 0.6230 - val_accuracy: 0.7667 - val_loss: 0.6923
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7782 - loss: 0.6187 - val_accuracy: 0.7000 - val_loss: 0.7565
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7359 - loss: 0.6308 - val_accuracy: 0.5333 - val_loss: 0.8472
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.8133 - loss: 0.5272 - val_accuracy: 0.7000 - val_loss: 0.6317
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.6799 - loss: 0.6904 - val_accuracy: 0.5333 - val_loss: 1.1885
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.5938 - loss: 0.8618 - val_accuracy: 0.7333 - val_loss: 0.7025
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7355 - loss: 0.6417 - val_accuracy: 0.5333 - val_loss: 0.9637
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7252 - loss: 0.6204 - val_accuracy: 0.6333 - val_loss: 0.6815
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7267 - loss: 0.5743 - val_accuracy: 0.8000 - val_loss: 0.6667
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7743 - loss: 0.5437 - val_accuracy: 0.7333 - val_loss: 0.6482
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8190 - loss: 0.4698 - val_accuracy: 0.7333 - val_loss: 0.6188
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.7875 - loss: 0.4830 - val_accuracy: 0.7000 - val_loss: 0.6597
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.8652 - loss: 0.4104 - val_accuracy: 0.7000 - val_loss: 0.6859
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.6502 - loss: 0.8172 - val_accuracy: 0.5000 - val_loss: 1.4101
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.6683 - loss: 0.7763 - val_accuracy: 0.6333 - val_loss: 0.7774
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7030 - loss: 0.6526 - val_accuracy: 0.7667 - val_loss: 0.6379
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6266 - loss: 0.9145 - val_accuracy: 0.4000 - val_loss: 1.3727
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.5512 - loss: 1.0032 - val_accuracy: 0.7000 - val_loss: 0.7775
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.7517 - loss: 0.6451 - val_accuracy: 0.7667 - val_loss: 0.6339
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7645 - loss: 0.5710 - val_accuracy: 0.5333 - val_loss: 0.9636
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.7115 - loss: 0.6387 - val_accuracy: 0.6000 - val_loss: 0.8248
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.6374 - loss: 0.8096 - val_accuracy: 0.5000 - val_loss: 0.9860
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.6475 - loss: 0.7127 - val_accuracy: 0.7667 - val_loss: 0.5748
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7896 - loss: 0.5400 - val_accuracy: 0.7667 - val_loss: 0.5923
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7055 - loss: 0.5759 - val_accuracy: 0.6667 - val_loss: 0.6852
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8240 - loss: 0.4429 - val_accuracy: 0.7667 - val_loss: 0.6761
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.8039 - loss: 0.4736 - val_accuracy: 0.7667 - val_loss: 0.6212
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8353 - loss: 0.4007 - val_accuracy: 0.7000 - val_loss: 0.6412
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8458 - loss: 0.4664 - val_accuracy: 0.8333 - val_loss: 0.5502
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8693 - loss: 0.4137 - val_accuracy: 0.7333 - val_loss: 0.7233
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7708 - loss: 0.5005 - val_accuracy: 0.5000 - val_loss: 1.2312
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7797 - loss: 0.5673 - val_accuracy: 0.7000 - val_loss: 0.6688
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7179 - loss: 0.8066 - val_accuracy: 0.4667 - val_loss: 1.3823
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.5637 - loss: 1.0003 - val_accuracy: 0.5667 - val_loss: 0.7201
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7975 - loss: 0.5839 - val_accuracy: 0.5667 - val_loss: 0.8738
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7963 - loss: 0.5435 - val_accuracy: 0.7667 - val_loss: 0.6710
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7825 - loss: 0.4846 - val_accuracy: 0.8333 - val_loss: 0.5201
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7912 - loss: 0.5404 - val_accuracy: 0.5333 - val_loss: 1.1204
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7832 - loss: 0.5224 - val_accuracy: 0.6667 - val_loss: 0.9487
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7981 - loss: 0.5722 - val_accuracy: 0.8000 - val_loss: 0.5903
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.6919 - loss: 0.6273 - val_accuracy: 0.5667 - val_loss: 1.1772
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.6531 - loss: 0.7995 - val_accuracy: 0.7667 - val_loss: 0.6101
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8355 - loss: 0.4227 - val_accuracy: 0.7667 - val_loss: 0.6008
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8102 - loss: 0.4962 - val_accuracy: 0.6667 - val_loss: 0.6974
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7584 - loss: 0.7040 - val_accuracy: 0.5333 - val_loss: 1.3009
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7801 - loss: 0.5362 - val_accuracy: 0.7333 - val_loss: 0.7338
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.7266 - loss: 0.6331 - val_accuracy: 0.8333 - val_loss: 0.5788
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7875 - loss: 0.4549 - val_accuracy: 0.7667 - val_loss: 0.6801
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8719 - loss: 0.3716 - val_accuracy: 0.8000 - val_loss: 0.6147
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8288 - loss: 0.4291 - val_accuracy: 0.7333 - val_loss: 0.7124
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.8135 - loss: 0.5437 - val_accuracy: 0.7333 - val_loss: 0.7224
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7983 - loss: 0.5713 - val_accuracy: 0.5000 - val_loss: 1.3784
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7477 - loss: 0.6994 - val_accuracy: 0.7333 - val_loss: 0.6406
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7612 - loss: 0.5078 - val_accuracy: 0.7667 - val_loss: 0.6344
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8353 - loss: 0.4613 - val_accuracy: 0.7000 - val_loss: 0.6486
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8004 - loss: 0.4296 - val_accuracy: 0.5667 - val_loss: 1.0190
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8187 - loss: 0.4509 - val_accuracy: 0.8667 - val_loss: 0.5255
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9118 - loss: 0.2981 - val_accuracy: 0.7667 - val_loss: 0.5819
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8649 - loss: 0.4773 - val_accuracy: 0.8333 - val_loss: 0.5033
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8765 - loss: 0.3630 - val_accuracy: 0.7667 - val_loss: 0.6400
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8432 - loss: 0.3382 - val_accuracy: 0.7667 - val_loss: 0.7066
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8266 - loss: 0.5297 - val_accuracy: 0.5667 - val_loss: 1.1984
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.7570 - loss: 0.5677 - val_accuracy: 0.6667 - val_loss: 0.7689
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7931 - loss: 0.4618 - val_accuracy: 0.7667 - val_loss: 0.6720
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7720 - loss: 0.5849 - val_accuracy: 0.5667 - val_loss: 1.1337
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.7812 - loss: 0.5324 - val_accuracy: 0.7667 - val_loss: 0.6371
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8888 - loss: 0.4243 - val_accuracy: 0.5667 - val_loss: 0.9634
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.8600 - loss: 0.3666 - val_accuracy: 0.7000 - val_loss: 0.6257
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8589 - loss: 0.3862 - val_accuracy: 0.7667 - val_loss: 0.5873
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7924 - loss: 0.5702 - val_accuracy: 0.6667 - val_loss: 0.7101
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8055 - loss: 0.4483 - val_accuracy: 0.8000 - val_loss: 0.5997
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.8087 - loss: 0.4863 - val_accuracy: 0.4667 - val_loss: 1.3733
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.8692 - loss: 0.3636 - val_accuracy: 0.7000 - val_loss: 0.7621
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.8816 - loss: 0.3024 - val_accuracy: 0.7333 - val_loss: 0.7081
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8290 - loss: 0.4530 - val_accuracy: 0.7667 - val_loss: 0.5517
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9053 - loss: 0.3173 - val_accuracy: 0.7333 - val_loss: 0.6046
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.9548 - loss: 0.2156 - val_accuracy: 0.8000 - val_loss: 0.5155
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.8027 - loss: 0.4698 - val_accuracy: 0.7667 - val_loss: 0.5899
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8857 - loss: 0.3617 - val_accuracy: 0.7667 - val_loss: 0.6411
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.8459 - loss: 0.3688 - val_accuracy: 0.7667 - val_loss: 0.5552
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8378 - loss: 0.3720 - val_accuracy: 0.6333 - val_loss: 0.9960
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.8515 - loss: 0.3651 - val_accuracy: 0.8000 - val_loss: 0.6891

# %%
np.save(root_path + f'models/CNN-BiLSTM_2', history.history)
model.save(root_path + 'models/CNN-BiLSTM_2.keras')

# %% [markdown]
# # Model Metrics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics1 = np.load(root_path + 'models/CNN-BiLSTM_1.npy', allow_pickle=True)
metrics1 = metrics1.all()
metrics2 = np.load(root_path + 'models/CNN-BiLSTM_2.npy', allow_pickle=True)
metrics2 = metrics2.all()

combined_dict = {}

for key in metrics1:
        combined_dict[key] = metrics1[key] + metrics2[key]

# %%
acc_list = combined_dict['accuracy']
val_acc_list = combined_dict['val_accuracy']

epochs = range(1, len(acc_list) + 1)
plt.plot(epochs, acc_list, 'r', label='Train')
plt.plot(epochs, val_acc_list, 'b', label='Validation')
plt.ylim(0, 1)
plt.title('CNN - LSTM')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
loss_list = combined_dict['loss']
val_loss_list = combined_dict['val_loss']

epochs = range(1, len(combined_dict['accuracy']) + 1)
plt.plot(epochs, loss_list, 'r', label='Train')
plt.plot(epochs, val_loss_list, 'b', label='Validation')
plt.title('CNN - LSTM')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 1.5)
plt.legend()
plt.show()

# %%
print('training Accuracy:', max(acc_list))
print('validation Accuracy:', max(val_acc_list))
print('')
print('training Loss:', min(loss_list))
print('validation Loss:', min(val_loss_list))
# Out:
# training Accuracy: 0.925000011920929
# validation Accuracy: 0.8666666746139526
#
# training Loss: 0.27548250555992126
# validation Loss: 0.503256618976593

# %% [markdown]
# # Model Evaluation

# %%
import cv2
import numpy as np
import tensorflow as tf
import imageio
from tensorflow.keras.models import load_model

# %%
# Load the pre-trained model (replace with the actual model you're using)
# For example, let's assume we have a model saved as 'action_recognition_model.h5'
model = load_model(root_path + 'models/CNN-BiLSTM_2.keras')

# %%
def recognize_action(frames, model):
    # Preprocess the frames for the model (resize, normalize, etc.)
    resized_frames = np.array([cv2.resize(frame, (WIDTH, HEIGHT)) for frame in frames])  # Resize to match model input size
    normalized_frames = resized_frames / 255.0  # Normalize pixel values
    input_frames = np.expand_dims(normalized_frames, axis=0)  # Add batch dimension

    # Perform inference
    predictions = model.predict(input_frames)
    predicted_class = np.argmax(predictions, axis=1)[0]
    print(predictions)

    return class_labels[predicted_class] + f'({predictions[0][predicted_class]:.2f})'

def annotate_frame(frame, text):
    annotated_frame = frame.copy()
    cv2.putText(annotated_frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2, cv2.LINE_AA)
    return annotated_frame

def create_gif_from_video(video_path, output_gif_path, model):
    cap = cv2.VideoCapture(video_path)
    frames = []
    gif_frames = []
    sequence_length = 15
    steps = 2
    step_counter = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if step_counter % steps == 0:
            frames.append(frame)

        # If we have enough frames for a sequence, perform action recognition
        if len(frames) == sequence_length:
            action_class = recognize_action(frames, model)

            # Annotate each frame in the sequence
            annotated_frames = [annotate_frame(f, action_class) for f in frames]
            frames = []  # Clear the frames list

            # Add annotated frames to the GIF frames list
            gif_frames.extend([cv2.cvtColor(af, cv2.COLOR_BGR2RGB) for af in annotated_frames])

    cap.release()

    # Save frames as a GIF
    imageio.mimsave(output_gif_path, gif_frames, fps=25)
    print(f"GIF saved to {output_gif_path}")

def combine_videos_sequentially(video_paths, output_path):
    # Capture all the input videos
    caps = [cv2.VideoCapture(video) for video in video_paths]

    # Get properties from the first video
    frame_width = int(caps[0].get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(caps[0].get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = caps[0].get(cv2.CAP_PROP_FPS)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    for cap in caps:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)
        cap.release()  # Release each video capture object after reading

    out.release()
    cv2.destroyAllWindows()

# %%
# @title ## Push Ups

# Path to the video file
video_path = '/content/UCF101_subset/train/PushUps/v_PushUps_g01_c02.avi'

# Output path for the GIF
output_gif_path = root_path + 'metrics/3DCNN-BiLSTM_PushUps.gif'

# Create the GIF from the video
create_gif_from_video(video_path, output_gif_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 45s 45s/step
# [[ 0.40212765  1.6486818  -1.4302238 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [[ 0.54637116  1.6241513  -1.6119561 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [[ 0.4470354  1.6268296 -1.5353178]]
# GIF saved to /content/drive/MyDrive/3RD YR. - 2ND SEM./CPE 313/Final Project/metrics/3DCNN-BiLSTM_PushUps.gif

# %%
# @title ## Squats

# Path to the video file
video_path = '/content/UCF101_subset/test/BodyWeightSquats/v_BodyWeightSquats_g06_c04.avi'

# Output path for the GIF
output_gif_path = root_path + 'metrics/3DCNN-BiLSTM_Squats.gif'

# Create the GIF from the video
create_gif_from_video(video_path, output_gif_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# [[ 1.6546618  0.5775479 -1.4732865]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[ 1.6359359  0.5784872 -1.4724553]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# [[ 1.4734364   0.69022256 -1.4525715 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [[ 1.5658801  0.6581421 -1.480055 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [[ 1.6527195  0.5747977 -1.480045 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [[ 1.6604233  0.5422706 -1.4424522]]
# GIF saved to /content/drive/MyDrive/3RD YR. - 2ND SEM./CPE 313/Final Project/metrics/3DCNN-BiLSTM_Squats.gif

# %%
# @title ## Lunges

# Path to the video file
video_path = '/content/UCF101_subset/test/Lunges/v_Lunges_g08_c01.avi'

# Output path for the GIF
output_gif_path = root_path + 'metrics/3DCNN-BiLSTM_Lunges.gif'

# Create the GIF from the video
create_gif_from_video(video_path, output_gif_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[ 1.3568748   0.69877076 -1.3335092 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[ 1.1632698  1.0229437 -1.5206944]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[ 0.68030936  1.1340433  -1.3058931 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[ 1.3255264   0.57366353 -1.1525404 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[ 0.7040765  1.1388007 -1.3256971]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[ 0.64236355  1.1321512  -1.2895998 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[ 1.5579746   0.59904206 -1.3006302 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[ 0.89601105  1.0841577  -1.4032339 ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[ 0.6836404  1.1976389 -1.3657417]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[ 1.4086636   0.0659852  -0.74450433]]
# GIF saved to /content/drive/MyDrive/3RD YR. - 2ND SEM./CPE 313/Final Project/metrics/3DCNN-BiLSTM_Lunges.gif

# %% [markdown]
# Google Colab Link: https://colab.research.google.com/drive/14qKwqgpnbH9A1VYGzTNvU8N5vmL2gnMN?usp=sharing
